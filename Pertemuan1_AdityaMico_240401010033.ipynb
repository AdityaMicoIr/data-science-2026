# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityaMicoIr/data-science-2024/blob/main/Pertemuan1_AdityaMico_240401010033.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SEL 1: Output sederhana
print("Hello, Data Science!")

# SEL 2: Variabel & tipe data
nama = "Aditya Mico Irwansyah"
angkatan = 2024
print(f"Halo, {nama} angkatan {angkatan}!")

# SEL 3: List & perulangan
tools = ["Python","Colab","Jupyter","GitHub"]
for i, tool in enumerate(tools, 1):
    print(f" {i}. {tool}")

# SEL 4: Fungsi Python
def perkenalan(nama, prodi, angkatan):
    return f"{nama} | {prodi} | {angkatan}"

print(perkenalan("Aditya","Informatika",2024))
# Out:
# Hello, Data Science!
# Halo, Aditya Mico Irwansyah angkatan 2024!
#  1. Python
#  2. Colab
#  3. Jupyter
#  4. GitHub
# Aditya | Informatika | 2024
